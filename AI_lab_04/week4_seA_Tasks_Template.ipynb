# %% [markdown]
# ## Task 1: Smart Warehouse Inventory Retrieval Agent

# %%
from collections import deque

# 1. STATE-SPACE REPRESENTATION

graph = {
    "Warehouse Entrance": {
        "Zone A": 2
    },

    "Zone A": {
        "Warehouse Entrance": 2,
        "Zone B": 4,
        "Zone C": 3
    },

    # add other states and transitions as needed (given in the Lab Task doc. in Graph Visual)
}

# 2. Define INITIAL STATE AND GOAL STATE


# 3. GOAL TEST


def goal_test(state):
    pass


# 4. SEARCH PROCEDURE


def search(graph, initial_state, goal_state):

    pass

# 5. PATH COST CALCULATION
# Calculate and display the total path cost of the solution returned by the search procedure.
def calculate_path_cost(path):

    pass

# 6. DISPLAY PROBLEM FORMULATION

print("MART WAREHOUSE INVENTORY RETRIEVAL")

#print  Initial State
#print Goal State
#print Possible Actions

#print("\nState-Space Graph:")

for state, neighbors in graph.items():

    pass



# 7. SEARCH FOR SOLUTION

solution = search(
    graph,
    #pass initial state,
    #pass goal state
)



# 8. DISPLAY SOLUTION

print("\nSearch Algorithm:")
print("Queue-based graph search")

if solution:

    print("\nSolution Path:")
    print(" -> ".join(solution))

    total_cost = calculate_path_cost(solution)

    print("\nTotal Travel Distance:")
    print(total_cost, "meters")

else:

    print("\nNo solution found.")

# %% [markdown]
# ## Task 2: Cloud Resource Deployment Planning Agent

# %%
from collections import deque

# 1. STATE-SPACE REPRESENTATION


graph = {
    "Deployment Request": {
        "Standard Resources": 2,
        "High-Performance Resources": 5
    },

    "Standard Resources": {
        "Standard VM": 3
    },

    "High-Performance Resources": {
        "High-Performance VM": 7
    },

    "Standard VM": {
        "Install Dependencies": 4
    },

    "High-Performance VM": {
        "Install Dependencies": 4
    },

    "Install Dependencies": {
        "Standard Deployment": 6,
        "Optimized Deployment": 9
    },

    # add other states and transitions as needed (given in the Lab Task doc. in Graph Visual)
}


# 2. Define INITIAL AND GOAL STATES


# 3. GOAL TEST
def goal_test(state):
    pass

# 4. SEARCH PROCEDURE
def search(graph, initial_state, goal_state):

    pass
# 5. PATH COST CALCULATION

def calculate_path_cost(path):

    pass

# 6. DISPLAY PROBLEM FORMULATION

print(" CLOUD RESOURCE DEPLOYMENT PLANNING ")

#print Initial State
#print Goal State
#print Possible Actions


#print State-Space Graph

for state, neighbors in graph.items():

    pass
# 7. SEARCH FOR SOLUTION
solution = search(
    graph,
    #pass initial state,
    #pass goal state
)

# 8. DISPLAY SOLUTION

print("\nSearch Algorithm:")
print("Queue-based graph search")

if solution:

    print("\nSolution Path:")
    print(" -> ".join(solution))

    total_cost = calculate_path_cost(solution)

    print("\nTotal Deployment Cost:")
    print(total_cost, "units")

else:

    print("\nNo solution found.")
